# %%
# Clone git hub yolov5 into google drive (if its not downloaded before)
#!git clone https://github.com/ultralytics/yolov5  # clone
#!cd {path_YOLO_dir}
#!pip install -r yolov5/requirements.txt  # install
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17067, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 17067 (delta 24), reused 27 (delta 12), pack-reused 17022 (from 1)
# Receiving objects: 100% (17067/17067), 15.69 MiB | 27.79 MiB/s, done.
# Resolving deltas: 100% (11718/11718), done.
# /bin/bash: line 1: cd: {path_YOLO_dir}: No such file or directory
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.5/898.5 kB 18.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# 1. CONNECT TO GOOGLE DRIVE

# %%
# Connecting to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 2. IMPORTING DEPENDENDCIES AND MAKE PATHS TO THE FOLDERS

# %%
#Imports
import os

#Directory to face dataset
data_dir = os.path.join('/content/drive/MyDrive/archive')


# Make the path to the folders both labels and images, train and validation
train_img_dir = os.path.join('/content/drive/MyDrive/archive/images/train')
train_label_dir = os.path.join('/content/drive/MyDrive/archive/labels/train')
val_img_dir = os.path.join('/content/drive/MyDrive/archive/images/val')
val_label_dir = os.path.join('/content/drive/MyDrive/archive/labels/val')


# Path to the pre trained model YOLOv5
path_YOLO_dir = os.path.join('/content/drive/MyDrive/yolov5')

# Path to dataset (.yaml) - paths to dataset and class named dictionary
path_dataset = os.path.join('/content/drive/MyDrive/Facedetec_dataset.yaml')

# %% [markdown]
# 3. CHECK IMAGES AND LABELS AND VERIFY THE PATH TO THE DATASET

# %%
# Print images and labels to see how many there are in each folder and verify the dataset path

print(f'total training images: {len(os.listdir(train_img_dir))}')
print(f'total training labels: {len(os.listdir(train_label_dir))}')

print(f'total validation images: {len(os.listdir(val_img_dir))}')
print(f'total validation labels: {len(os.listdir(val_label_dir))}')
# Out:
# total training images: 13478
# total training labels: 13396
# total validation images: 3357
# total validation labels: 3377

# %% [markdown]
# 4. TRAINING THE MODEL

# %%
# Using CUDA GPU for faster training
import torch
device = "cuda:0" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")


# To acces the directory where the yolov5 file is located.
# %cd "{path_YOLO_dir}"

# Trains the model using YOLOv5
# !python train.py \
--cfg "/content/drive/MyDrive/yolov5/models/yolov5s.yaml" \
--data "{path_dataset}" \
--epochs 30 \
--batch-size 64 \
--imgsz 640 \
--weights "" \
--device {device} \
--name "Training_logs_outputs" \
--project "/content/drive/MyDrive/Training"


print("Training is complete.")
# Out:
# Streaming output truncated to the last 5000 lines.
#       18/29      21.2G      0.033     0.0246          0        342        640:  32% 67/211 [00:44<02:06,  1.14it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       18/29      21.2G      0.033    0.02459          0        333        640:  32% 68/211 [00:44<01:37,  1.46it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       18/29      21.2G    0.03297    0.02457          0        323        640:  33% 69/211 [00:44<01:18,  1.81it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...
